# %% [markdown]
# # **1. Problem Definition.**

# %% [markdown]
# # **Define the Problem**
# **Problem Statement : -**
#
# 1. **Improper waste segregation** is a major environmental issue affecting cities and communities.
# 2. Many people are unable to correctly identify whether waste is **organic** or **recyclable**.
#
# 3. This leads to:
#    * **Increased landfill waste**.
#    * **Environmental pollution**.
#    * **Inefficient recycling processes**.
# 4. Manual sorting of waste is:
#     * **Time-consuming**.
#     * **Error-prone**.
#     * **Not scalable for large populations**.
#
# ---
# **Project Objective : -**
# 1. To develop a **Deep Learning-based image classification system**.
# 2. The system will use a **Convolutional Neural Network (CNN)** to:
#    * Automatically **classify waste images**.
#    * Identify categories such as **organic** and **recyclable**.
# 3. To provide **basic recycling recommendations** based on the predicted class.
#
# ---
# **Expected Outcomes : -**
#
# 1. Build a model that can **accurately classify waste images**.
#
# 2. Achieve good performance using metrics like:
#     * **Accuracy**.
#
#     * **Precision**.
#
#     * **Recall**.
# 3. Reduce **human effort** in waste segregation.
# 4. Improve **efficiency in waste management systems**.
# 5. Encourage **environmentally responsible disposal practices**.
#
# ---
# **Real-World Applications: -**
# 1. Can be used in:
#   * **Smart city waste management systems**.
# * **Recycling centers**.
# * **Public awareness mobile applications**.
# 2. Helps promote:
# * **Sustainability**.
# * **Clean environment**.
# * **Efficient resource utilization**.
#
# ---
# **Short Summary : -**
#
# 1. This project focuses on solving the problem of **improper waste segregation** using **Deep Learning**.
# 2. A CNN-based model will classify waste images into categories like **organic** and **recyclable**.
# 3. The system aims to provide an **accurate, automated, and scalable solution** to improve waste management and support **environmental sustainability**.

# %% [markdown]
# # **2. Data Collection.**

# %% [markdown]
# # **Collect Data**
# **Dataset Selection : -**
#
# 1. The dataset used for this project is the **Waste Classification Dataset** from Kaggle.
# 2. It contains a large number of **labeled waste images**, suitable for training a deep learning model.
# 3. Dataset link:
#     * **https://www.kaggle.com/datasets/techsash/waste-classification-data**.
#
# ---
# **Dataset Description : -**
# 1. The dataset consists of **25,000+ images**, satisfying the requirement of large data for deep learning.
# 2. Images are categorized into classes such as:
#    * **Organic Waste**.
#    * **Recyclable Waste**.
# 3. Each image is **properly labeled**, which is essential for supervised learning.
#
# ---
# **Data Quality: -**
# 1. The dataset contains:
# * **Clear and diverse images** of waste materials.
# * Different **backgrounds, lighting conditions, and angles**.
# 2. This diversity helps the model to:
# * **Generalize better**.
# * Perform well on **real-world data**.
#
# ---
# **Why This Dataset is Suitable**
# 1. Meets the requirement of **minimum 10,000 samples**.
# 2. Well-structured and **easy to use in Google Colab**.
# 3. Suitable for **image classification using CNN**.
# 4. Widely used in **academic and research projects**.
#
# ---
# **Data Collection Method : -**
# 1. The dataset is collected from **Kaggle**, a trusted platform for machine learning datasets.
# 2. It is downloaded and uploaded into **Google Colab** for further processing.
#
# ---
# **Short Summary : -**
# 1. The project uses the **Waste Classification Dataset from Kaggle**, which contains over **25,000 labeled images** of waste.
# 2. The dataset includes categories like **organic** and **recyclable**, making it suitable for supervised learning.
# 3. Its size, quality, and diversity ensure effective training of a **deep learning model**.

# %%
#Install Kaggle.
# !pip install kaggle --quiet

# %%
#Setting Kaggle credentials.
import os

os.environ['KAGGLE_API_TOKEN'] = 'KGAT_1d6590de5fed5d78fb86eb0d8cdff3d2'

# %%
#Downloading dataset.
# !kaggle datasets download -d techsash/waste-classification-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/techsash/waste-classification-data
# License(s): CC-BY-SA-4.0
# ...
# 100% 427M/427M [00:04<00:00, 95.3MB/s]

# %%
#Unzip the Dataset.
# !unzip -o waste-classification-data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/DATASET/TRAIN/R/R_5499.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_55.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_550.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5500.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5501.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5502.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5503.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5504.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5505.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5506.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5507.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5508.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5509.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_551.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5510.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5511.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5512.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5513.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5514.jpg
# ...

# %%
#Define dataset_path.
dataset_path = "/content/dataset/DATASET/TRAIN"

# %%
#Download additional recyclable dataset.

# !kaggle datasets download -d meetpatelp27/image-waste-classification-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/meetpatelp27/image-waste-classification-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100% 213M/213M [00:01<00:00, 123MB/s]

# %%
import os

os.listdir('/content')
# Out:
# ['.config',
#  'dataset',
#  'waste-classification-data.zip',
#  'image-waste-classification-dataset.zip',
#  'DATASET',
#  'sample_data']

# %%
# !unzip -o image-waste-classification-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: waste_dataset/recyclable/recyclable_005917_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005918_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005919_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005920_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005921_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005922_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005923_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005924_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005925_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005926_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005927_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005928_photo.jpg
#   inflating: waste_dataset/recyclable/recyclable_005929_photo.jpg
# ...

# %%
import shutil
import os

#Source recyclable folder
source_folder = "/content/waste_dataset/recyclable"

#Destination R folder
destination_folder = "/content/dataset/DATASET/TRAIN/R"

#Copy all images
for filename in os.listdir(source_folder):

    source_path = os.path.join(source_folder, filename)

    destination_path = os.path.join(destination_folder, filename)

    shutil.copy(source_path, destination_path)

print("Recyclable images added successfully!")
# Out:
# Recyclable images added successfully!

# %%
for category in os.listdir(dataset_path):
    print(category, ":", len(os.listdir(os.path.join(dataset_path, category))))
# Out:
# R : 20824
# O : 12565

# %% [markdown]
# # **3. EDA (Exploratory Data Analysis).**

# %%
#Visualize Class Distribution.
import matplotlib.pyplot as plt

classes = ['Organic (O)', 'Recyclable (R)']
counts = [12565, 9999]

plt.figure(figsize=(6,4))
plt.bar(classes, counts)
plt.title("Class Distribution")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %%
#Check Sample Image Size and Mode.
from PIL import Image
import os

#Select one sample image from Organic class.
sample_image_path = os.path.join(
    dataset_path,
    'O',
    os.listdir(os.path.join(dataset_path, 'O'))[0]
)

#Open image.
img = Image.open(sample_image_path)

#Display image properties.
print("Image Size:", img.size)
print("Image Mode:", img.mode)
# Out:
# Image Size: (225, 225)
# Image Mode: RGB

# %%
#Verify Classes & Image Count.
import os

for category in os.listdir(dataset_path):
    print(category, ":", len(os.listdir(os.path.join(dataset_path, category))))
# Out:
# R : 20824
# O : 12565

# %% [markdown]
# # **EDA (Exploratory Data Analysis) - Summary**
#
# * **Exploratory Data Analysis (EDA)** was performed to understand the dataset before preprocessing and model building.
#
# * The **class distribution** of the dataset was visualized using a bar chart to check the number of images in each category.
#
# * The dataset contains two classes:
#
#   * **Organic Waste (O)** → 12,565 images
#   * **Recyclable Waste (R)** → 9,999 images
#
# * This confirms that the dataset contains a **large number of labeled images**, which is suitable for deep learning.
#
# * A sample image was analyzed to check the **image size and image mode**.
#
# * The output showed:
#
#   * **Image Size:** (243, 207)
#   * **Image Mode:** RGB
#
# * This confirms that the images are in **RGB color format**, which is suitable for CNN-based image classification.
#
# * The folder structure and image counts were verified successfully using Python and OS library functions.
#
# * EDA helped in understanding:
#
#   * **Dataset structure**
#   * **Class distribution**
#   * **Image properties**
#   * **Data readiness for preprocessing and model training**

# %% [markdown]
# # **4. Data Preprocessing.**

# %% [markdown]
# # **Pre-process the Data**
# **Objective : -**
# * Prepare the dataset for training by:
#    1. **Cleaning the data**.
#    2. **Resizing images**.
#    3. **Normalizing pixel values**.
#    4. Applying **data augmentation**.

# %%
#Remove Corrupted Images (Data Cleaning).
from PIL import Image
import os

def remove_corrupt_images(path):
    for category in os.listdir(path):
        category_path = os.path.join(path, category)
        for img_name in os.listdir(category_path):
            img_path = os.path.join(category_path, img_name)
            try:
                with Image.open(img_path) as img:
                    img.verify()
            except:
                os.remove(img_path)
                print("Removed:", img_path)

remove_corrupt_images(dataset_path)

# %%
#Import Required Libraries.
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

#Import required libraries for model building.
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout,GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNetV2

from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import roc_auc_score
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
#Define Image Size & Augmentation.
img_size = (224, 224) #Resizing images to 224x224.
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,          #Normalize.
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2     #80-20 split.
)

# %%
#Create Training Data.
train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 26712 images belonging to 2 classes.

# %%
#Check Class Indices (Label Mapping).
print("Class Indices:", train_generator.class_indices)
# Out:
# Class Indices: {'O': 0, 'R': 1}

# %%
#Create Validation Data.
validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 6677 images belonging to 2 classes.

# %%
#Calculate Class Weights.
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

#Class labels from training generator.
class_labels = train_generator.classes

#Compute weights.
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(class_labels),
    y=class_labels
)

#Convert to dictionary.
class_weights = dict(enumerate(class_weights))

print("Class Weights:", class_weights)
# Out:
# Class Weights: {0: np.float64(1.3286908077994428), 1: np.float64(0.8016806722689076)}

# %%
#Visualize Processed Images.
images, labels = next(train_generator)

plt.figure(figsize=(10,5))
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# ##**Preprocessing Summary**
#
# * **Dataset Acquisition:**
#
#   -> The dataset was downloaded from **Kaggle** using the API and extracted successfully for further processing.
#
# * **Dataset Structure Verification:**
#   -> The folder structure was checked to ensure the correct path to the dataset.
#
#   -> The training data was accessed from:
#
#   **`/content/dataset/DATASET/TRAIN`**
#
# * **Class Distribution Verification:**
#
#   -> The dataset contains two classes:
#
#   * **Organic (O): 12,565 images**.
#   * **Recyclable (R): 9,999 images**.
#
#     -> This confirms that the dataset has **more than 10,000 samples**, satisfying deep learning requirements.
#
# * **Data Cleaning (Noise Removal):**
#
#   -> Corrupted or unreadable images were identified using the **PIL library** and removed.
#
#   -> This ensures **high-quality data** and prevents errors during training.
#
# * **Handling Outliers:**
#
#   -> In image datasets, **invalid or corrupted images** are treated as outliers. These were successfully removed during the cleaning process.
#
# * **Handling Missing Values:**
#
#   -> Not applicable, as the dataset consists of **image files** rather than structured tabular data.
#
# * **Data Transformation (Resizing):**
#
#   -> All images were resized to a uniform size of **224 * 224 pixels**, ensuring consistency for model input.
#
# * **Normalization:**
#
#   ->Pixel values were scaled from **0-255 to 0-1 range** using:
#
#   **`rescale = 1./255`**.
#
#   -> This improves **training stability and convergence speed**.
#
# * **Data Augmentation:**
#
#   -> To improve model robustness and generalization, the following techniques were applied:
#
#   * **Rotation (20°)**.
#   * **Width & Height Shifting (10%)**.
#   * **Shearing**.
#   * **Zooming (20%)**.
#   * **Horizontal Flipping**.
#
# * **Data Splitting:**
#
#   -> The dataset was automatically split into:
#
#   * **Training Set (80%) → 18,052 images**.
#   * **Validation Set (20%) → 4,512 images**.
#
# * **Label Encoding:**
#
#   -> Class labels were converted into numerical format:
#
#   * **Organic (O) → 0**.
#   * **Recyclable (R) → 1**.
#
# * **Data Loading for Deep Learning:**
#
#   -> The **ImageDataGenerator** was used to:
#
#   * Convert images into **numerical arrays**.
#   * Generate data in **batches (batch size = 32)**.
#   * Prepare data in a format suitable for **CNN models**.
#
# * **Data Visualization:**
#
#   -> Sample images were visualized after preprocessing to confirm:
#
#   * **Correct resizing**.
#   * **Proper normalization**.
#   * **Augmentation effects**.
#   * **Accurate class labels**.

# %% [markdown]
# # **5. Feature Engineering.**

# %%
#Load MobileNetV2 without top layers (Pre-trained on ImageNet).
base_model = MobileNetV2(
    weights='imagenet',      #Use pre-trained ImageNet weights.
    include_top=False,
    input_shape=(224, 224, 3)
)

#Freeze the entire base model.
base_model.trainable = False

#Verify freezing.
print("Base Model Trainable Status:", base_model.trainable)
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Base Model Trainable Status: False

# %% [markdown]
# # **8. Model Building.**

# %%
#Build the Model.
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')  #2 classes: O and R.
],name="Waste_Classification_Model")

# %%
#Compile the Model.
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Display model architecture.
model.summary()
# Out:
# Model: "Waste_Classification_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ...

# %%
#Check Trainable Layers.
print("Trainable layers:")
for layer in model.layers:
    print(layer.name, layer.trainable)
# Out:
# Trainable layers:
# mobilenetv2_1.00_224 False
# global_average_pooling2d True
# dense True
# dropout True
# dense_1 True

# %%
#Compile the model.
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## **Choose Framework and Architecture - Summary**
#
# * **Deep Learning Framework Selected:**
#
#   * Used **TensorFlow with Keras API** for model development.
#   * Chosen because it is **beginner-friendly**, widely used, and provides **high-level abstractions** for fast model building.
#
# * **Model Type (Architecture):**
#
#   * Selected a **Convolutional Neural Network (CNN)** since the task is **image classification**.
#   * CNNs are effective in capturing **spatial features** like shapes, edges, and textures in images.
#
# * **Transfer Learning Applied:**
#
#   * Used **MobileNetV2**, a **pre-trained model on ImageNet dataset**.
#   * This allows leveraging **pre-learned features**, improving performance and reducing training time.
#
# * **Base Model Configuration:**
#
#   * Loaded **MobileNetV2 without top layers (`include_top=False`)** to customize for our task.
#   * Input shape set to **(224, 224, 3)** matching preprocessed image size.
#
# * **Freezing Pre-trained Layers:**
#
#   * Set **`base_model.trainable = False`** to freeze all layers.
#   * Ensures **pre-trained weights are preserved** and only custom layers are trained.
#
# * **Custom Classification Head Added:**
#
#   * Added **GlobalAveragePooling2D** to reduce feature maps.
#   * Added **Dense layer (128 neurons, ReLU activation)** for learning patterns.
#   * Added **Dropout (0.5)** to prevent overfitting.
#   * Final **Dense layer (2 neurons, Softmax)** for **binary classification (O and R classes)**.
#
# * **Model Summary Verification:**
#
#   * Confirmed architecture using `model.summary()`.
#   * Observed:
#
#     * **Total parameters:** ~2.4 million
#     * **Trainable parameters:** ~164K (only custom layers)
#     * **Non-trainable parameters:** ~2.25M (frozen base model)
#
# * **Trainable Layers Check:**
#
#   * Verified that **MobileNetV2 is frozen (False)** and **custom layers are trainable (True)**.
#   * Confirms correct implementation of **transfer learning**.
#
# * **Model Compilation:**
#
#   * Compiled using:
#
#     * **Optimizer:** Adam
#     * **Loss Function:** Categorical Crossentropy
#     * **Metric:** Accuracy
#   * Prepares the model for **training and evaluation**.
#
# ---
#
# ##**Conclusion**
#
# * A **CNN-based transfer learning model** was successfully built using **MobileNetV2**.
# * The architecture is **efficient, optimized, and suitable for image classification tasks**, ensuring **high performance with minimal training time**.

# %% [markdown]
# # **9. Training.**

# %%
#Train the Model with Class Weights.

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=10,
    class_weight=class_weights
)
# Out:
# Epoch 1/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1772s 2s/step - accuracy: 0.9541 - loss: 0.1218 - val_accuracy: 0.9585 - val_loss: 0.1197
# Epoch 2/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1854s 2s/step - accuracy: 0.9546 - loss: 0.1173 - val_accuracy: 0.9624 - val_loss: 0.1079
# Epoch 3/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1673s 2s/step - accuracy: 0.9575 - loss: 0.1096 - val_accuracy: 0.9617 - val_loss: 0.1103
# Epoch 4/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1689s 2s/step - accuracy: 0.9588 - loss: 0.1128 - val_accuracy: 0.9579 - val_loss: 0.1171
# Epoch 5/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1835s 2s/step - accuracy: 0.9564 - loss: 0.1138 - val_accuracy: 0.9630 - val_loss: 0.1048
# Epoch 6/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1650s 2s/step - accuracy: 0.9570 - loss: 0.1109 - val_accuracy: 0.9685 - val_loss: 0.0947
# Epoch 7/10
# 835/835 ━━━━━━━━━━━━━━━━━━━━ 1745s 2s/step - accuracy: 0.9603 - loss: 0.1033 - val_accuracy: 0.9660 - val_loss: 0.1048
# Epoch 8/10
# ...

# %%
# Training Accuracy
train_accuracy = history.history['accuracy'][-1]

print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
# Out:
# Training Accuracy: 96.23%

# %%
#Visualize Training Performance.
import matplotlib.pyplot as plt

#Plot training & validation accuracy.
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

#Plot training & validation loss.
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## **Training - Summary.**
#
# * The model was trained using the `model.fit()` function with the training and validation datasets.
#
# * The following code was used:
#
# ```python id="1d23wt"
# history = model.fit(
#     train_generator,
#     validation_data=validation_generator,
#     epochs=10
# )
# ```
#
# * The model was trained for **10 epochs**.
#
# * During training, the model learned patterns from waste images and improved its classification performance in each epoch.
#
# * The training process used:
#
#   * **Training Dataset:** 18,052 images
#   * **Validation Dataset:** 4,512 images
#
# * The output showed gradual improvement in model performance during training.
#
# * The final epoch achieved approximately:
#
#   * **Training Accuracy:** 95.1%
#   * **Validation Accuracy:** 93.7%
#
# * The training loss decreased from approximately **0.2467** to **0.1282**, showing that the model learned effectively.
#
# * The validation loss remained relatively stable, indicating good performance on unseen data.
#
# * Training and validation accuracy graphs were plotted to visualize model learning performance across epochs.
#
# * The graphs showed:
#
#   * Increasing training accuracy
#   * Decreasing training loss
#   * Stable validation accuracy around 93%–94%
#
# * A slight fluctuation in validation loss was observed in later epochs, indicating minor overfitting, but the overall model performance remained good.
#
# * The training process successfully prepared the CNN model for evaluation and prediction tasks.

# %% [markdown]
# # **10. Evaluation.**

# %%
#Evaluate the Model on Validation Data.
loss, accuracy = model.evaluate(validation_generator)

print("Validation Loss:", loss)
print("Validation Accuracy:", accuracy)
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.9583 - loss: 0.1194
# Validation Loss: 0.11942627280950546
# Validation Accuracy: 0.9583414793014526

# %%
#Create Non-Shuffled Validation Generator for Evaluation.
evaluation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)
# Out:
# Found 5113 images belonging to 2 classes.

# %%
#Generate Predictions.
predictions = model.predict(evaluation_generator)

#Convert predictions to class labels.
y_pred = np.argmax(predictions, axis=1)

#True labels.
y_true = evaluation_generator.classes
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step

# %%
#Classification Report.

class_labels = list(evaluation_generator.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
#               precision    recall  f1-score   support
#
#            O       0.96      0.96      0.96      2513
#            R       0.96      0.96      0.96      2600
#
#     accuracy                           0.96      5113
#    macro avg       0.96      0.96      0.96      5113
# weighted avg       0.96      0.96      0.96      5113

# %%
#Confusion Matrix.
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
#ROC-AUC Score.

#Convert true labels to categorical format.
y_true_cat = to_categorical(y_true)

#Calculate ROC-AUC score.
roc_auc = roc_auc_score(y_true_cat, predictions)

print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.9919730861060945

# %%
#Error Analysis - Display Misclassified Images.

evaluation_generator.reset()

images, labels = next(evaluation_generator)

pred_probs = model.predict(images)
pred_classes = np.argmax(pred_probs, axis=1)
true_classes = np.argmax(labels, axis=1)

plt.figure(figsize=(12,8))

count = 1
for i in range(len(images)):
    if pred_classes[i] != true_classes[i]:

        plt.subplot(3,3,count)
        plt.imshow(images[i])

        plt.title(f"True: {class_labels[true_classes[i]]}\nPred: {class_labels[pred_classes[i]]}")

        plt.axis('off')

        count += 1

    if count > 9:
        break

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %% [markdown]
# ## **Evaluation - Summary**
#
# * The trained model was evaluated using the validation dataset.
#
# * Model evaluation was performed using:
#
#   * **Validation Accuracy**
#   * **Validation Loss**
#   * **Classification Report**
#   * **Confusion Matrix**
#   * **ROC-AUC Score**
#   * **Error Analysis**
#
# * The evaluation result showed:
#
#   * **Validation Accuracy:** ~93.7%
#   * **Validation Loss:** ~0.18
#
# * The classification report showed strong performance for both classes:
#
#   * **Organic Waste (O)**
#   * **Recyclable Waste (R)**
#
# * The model achieved approximately:
#
#   * **Precision:** 94%
#   * **Recall:** 94%
#   * **F1-Score:** 94%
#
# * The confusion matrix confirmed that most images were classified correctly.
#
# * Only a small number of images were misclassified between Organic and Recyclable categories.
#
# * The **ROC-AUC Score** was:
#
#   * **0.982**
#
# * This indicates excellent classification capability of the model.
#
# * Learning curves for:
#
#   * Training Accuracy
#   * Validation Accuracy
#   * Training Loss
#   * Validation Loss
#
#   were visualized to monitor model performance during training.
#
# * Error analysis was performed by displaying misclassified images.
#
# * Some images were incorrectly predicted because certain waste items had similar visual features.
#
# * Overall, the model showed:
#
#   * **High accuracy**
#   * **Good generalization**
#   * **Low overfitting**
#   * **Strong classification performance**

# %% [markdown]
# # **11. Hyperparameter Tuning.**

# %%
#Fine-Tuning MobileNetV2 Layers.

#Unfreeze last few layers of MobileNetV2.
base_model.trainable = True

#Freeze initial layers and train only last layers.
for layer in base_model.layers[:-20]:
    layer.trainable = False

#Check trainable status.
print("Last 20 layers are trainable for fine-tuning.")
# Out:
# Last 20 layers are trainable for fine-tuning.

# %%
#Recompile Model with Lower Learning Rate.
model.compile(
    optimizer=Adam(learning_rate=0.00001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Train Fine-Tuned Model with Class Weights.

fine_tune_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=5,
    class_weight=class_weights
)
# Out:
# Epoch 1/5
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1580s 2s/step - accuracy: 0.9252 - loss: 0.2044 - val_accuracy: 0.9578 - val_loss: 0.1313
# Epoch 2/5
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1569s 2s/step - accuracy: 0.9391 - loss: 0.1619 - val_accuracy: 0.9535 - val_loss: 0.1406
# Epoch 3/5
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1564s 2s/step - accuracy: 0.9455 - loss: 0.1434 - val_accuracy: 0.9589 - val_loss: 0.1274
# Epoch 4/5
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1559s 2s/step - accuracy: 0.9501 - loss: 0.1320 - val_accuracy: 0.9611 - val_loss: 0.1226
# Epoch 5/5
# 640/640 ━━━━━━━━━━━━━━━━━━━━ 1556s 2s/step - accuracy: 0.9532 - loss: 0.1226 - val_accuracy: 0.9611 - val_loss: 0.1166

# %%
#Visualize Fine-Tuning Performance.

import matplotlib.pyplot as plt

#Accuracy Plot.
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(fine_tune_history.history['accuracy'], label='Training Accuracy')
plt.plot(fine_tune_history.history['val_accuracy'], label='Validation Accuracy')

plt.title("Fine-Tuning Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

#Loss Plot.
plt.subplot(1,2,2)
plt.plot(fine_tune_history.history['loss'], label='Training Loss')
plt.plot(fine_tune_history.history['val_loss'], label='Validation Loss')

plt.title("Fine-Tuning Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
#Evaluate Fine-Tuned Model.

loss, accuracy = model.evaluate(evaluation_generator)

print("Fine-Tuned Validation Loss:", loss)
print("Fine-Tuned Validation Accuracy:", accuracy)
# Out:
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 0.9599 - loss: 0.1221
# Fine-Tuned Validation Loss: 0.12209267169237137
# Fine-Tuned Validation Accuracy: 0.9599061012268066

# %% [markdown]
# # **Hyperparameter Tuning - Summary.**
#
# * Hyperparameter tuning was performed to improve the performance of the waste classification model.
#
# * Fine-tuning was applied on the **MobileNetV2** pre-trained model.
#
# * Initially, the complete base model was frozen.
#
# * During tuning, the last **20 layers** of MobileNetV2 were unfrozen for additional training.
#
# * This allowed the model to learn more specific features from the waste image dataset.
#
# * A **smaller learning rate (0.00001)** was used during fine-tuning to make stable and gradual weight updates.
#
# * The model was recompiled using:
#
#   * **Adam Optimizer**
#   * **Categorical Crossentropy Loss**
#   * **Accuracy Metric**
#
# * The fine-tuned model was trained for **5 additional epochs**.
#
# * Fine-tuning performance was visualized using:
#
#   * Training Accuracy
#   * Validation Accuracy
#   * Training Loss
#   * Validation Loss
#
# * The final evaluation result showed:
#
#   * **Fine-Tuned Validation Accuracy:** ~94.5%
#   * **Fine-Tuned Validation Loss:** ~0.166
#
# * The fine-tuned model achieved better performance compared to the initial model.
#
# * Hyperparameter tuning improved:
#
#   * Model accuracy
#   * Feature learning capability
#   * Generalization performance
#
# * The model showed only slight overfitting and maintained stable validation performance.

# %%
#Save Model without Optimizer.
model.save("waste_classification_model.keras", include_optimizer=False)

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %% [markdown]
# # **12. Deployment.**

# %%
#Load Saved Model.


loaded_model = load_model("waste_classification_model.keras")

print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
#Upload Image from System.
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5194eec6-8d86-4b7d-ba92-e7dd8bb21b1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5194eec6-8d86-4b7d-ba92-e7dd8bb21b1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Test Model on Uploaded Image.

#Path of uploaded image.
img_path = list(uploaded.keys())[0]

#Load image.
img = image.load_img(img_path, target_size=(224,224))

#Convert image to array.
img_array = image.img_to_array(img)

#Normalize image.
img_array = img_array / 255.0

#Expand dimensions.
img_array = np.expand_dims(img_array, axis=0)

#Prediction.
prediction = loaded_model.predict(img_array)

#Class labels.
class_names = ['Organic (O)', 'Recyclable (R)']

predicted_class = class_names[np.argmax(prediction)]

#Display image.
plt.imshow(img)
plt.title(f"Predicted: {predicted_class}")
plt.axis('off')
plt.show()

print("Prediction:", predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Prediction: Organic (O)

# %% [markdown]
# ## **Saving Model - Summary**
#
# * The trained waste classification model was successfully saved using the **Keras model format**.
#
# * The model was saved using:
#
#   ```python
#   model.save("waste_classification_model.keras", include_optimizer=False)
#   ```
#
# * The parameter:
#
#   ```python
#   include_optimizer=False
#   ```
#
#   was used to avoid unnecessary optimizer warnings while loading the model.
#
# * The output:
#
#   ```python
#   Model saved successfully.
#   ```
#
#   confirms that the trained model was stored successfully.
#
# * Saving the model allows it to be reused later without training again.
#
# * The saved model contains the learned weights and architecture of the trained CNN model.

# %% [markdown]
# ## **Deployment - Summary**
#
# * The saved model was successfully loaded using:
#
#   ```python
#   load_model("waste_classification_model.keras")
#   ```
#
# * The output:
#
#   ```python
#   Model loaded successfully.
#   ```
#
#   confirms that the saved model was loaded correctly.
#
# * An image upload system was implemented using:
#
#   ```python
#   files.upload()
#   ```
#
# * This allows users to upload waste images directly from their system for prediction.
#
# * Uploaded images were:
#
#   * Resized to **224 × 224**
#   * Converted into array format
#   * Normalized using:
#
#     ```python
#     img_array = img_array / 255.0
#     ```
#
# * The image dimensions were expanded before prediction using:
#
#   ```python
#   np.expand_dims()
#   ```
#
# * The loaded model was used to predict the waste category.
#
# * The model classified uploaded images into:
#
#   * **Organic (O)**
#   * **Recyclable (R)**
#
# * The uploaded image and predicted class label were displayed successfully using Matplotlib.
#
# * Deployment testing confirmed that the trained model can successfully classify new waste images uploaded by the user.

# %% [markdown]
# Do dashboards,
# Gather insights as overall summary in last,
# Front end.

# %%
from google.colab import files

files.download("waste_classification_model.keras")

# %% [markdown]
# # **Interpretation of Results (Conclusion):**
#
# ---
# * **TensorFlow** and **Keras** frameworks were successfully used for building the deep learning model.
#
# * A **CNN-based Transfer Learning** approach was implemented using the **MobileNetV2** pre-trained model.
#
# * The **ImageNet pre-trained weights** helped improve feature extraction and reduced overall training time.
#
# * The **top layers** of MobileNetV2 were removed and replaced with custom classification layers for the waste classification task.
#
# * The **base model layers were frozen** to prevent modification of pre-trained weights during initial training.
#
# * **GlobalAveragePooling2D**, **Dense**, and **Dropout** layers were added to improve learning and reduce overfitting.
#
# * The final output layer used **Softmax Activation** for predicting the two classes: **Organic** and **Recyclable** waste.
#
# * The model architecture summary confirmed the successful integration of **trainable** and **non-trainable** parameters.
#
# * The developed model successfully supports **AI-based smart waste classification** using image data.
#
# * The project demonstrates the effective use of **Deep Learning**, **Transfer Learning**, and **Computer Vision** techniques for automated waste management solutions.

# %% [markdown]
# # **Future Work:**
#
# ---
# * The model can be improved by training on a **larger and more diverse waste image dataset** for better accuracy and generalization.
#
# * Additional waste categories such as **Plastic, Metal, Glass, Paper, and E-waste** can be included in future versions.
#
# * **Fine-tuning** the frozen layers of **MobileNetV2** can further improve model performance.
#
# * Other advanced pre-trained models such as **ResNet50**, **EfficientNet**, and **VGG16** can be tested and compared.
#
# * Real-time waste detection can be implemented using **live camera integration** and **video stream processing**.
#
# * The system can be deployed as a **mobile application** for easier accessibility and practical usage.
#
# * Integration with **IoT-based smart bins** can help automate waste segregation in real-world environments.
#
# * More evaluation metrics such as **F1-Score**, **ROC-AUC**, and **Confusion Matrix Analysis** can be added for deeper performance analysis.
#
# * The Streamlit application can be enhanced with **user authentication**, **cloud deployment**, and **real-time analytics dashboards**.
#
# * The project can be extended into a complete **Smart Waste Management System** for smart city applications.
